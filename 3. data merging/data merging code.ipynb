# %%
import pandas as pd

#read file
k_df=pd.read_csv("/Users/candicewu/Desktop/1415kc house data.csv")
k_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
k_df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Convert the date column to datetime format
k_df['date'] = pd.to_datetime(k_df['date'])
k_df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Sort the dataframe by the date column
k_df =k_df.sort_values(by='date')
k_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02   437500.0         3       2.25         1970
# 9596    472000620 2014-05-02   790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02   675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02   555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02   440000.0         4       2.25         2160
# ...           ...        ...        ...       ...        ...          ...
# 7898   1422700040 2015-05-14   183000.0         3       1.00         1170
# 928    8730000270 2015-05-14   359000.0         2       2.75         1370
# 5637   7923600250 2015-05-15   450000.0         5       2.00         1870
# 13053  5101400871 2015-05-24   445500.0         2       1.75         1390
# 16594  9106000005 2015-05-27  1310000.0         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Create a new column with only the year values
k_df['year'] = k_df['date'].apply(lambda x: x.year)
k_df.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02  437500.0         3       2.25         1970
# 9596    472000620 2014-05-02  790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02  675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02  555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02  440000.0         4       2.25         2160
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 16768     35100     2.0           0     0  ...        1970              0
# 9596       4750     1.0           0     0  ...        1700            900
# 9587      67518     2.0           0     0  ...        2820              0
# 20602      6500     2.0           0     0  ...        3310              0
# 11577      8119     1.0           0     0  ...        1080           1080
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
import pandas as pd
from datetime import date


# Define a function to calculate the age based on the build year
def get_age(yr_built):
    # Get the current year
    current_year = date.today().year

    # Calculate the age by subtracting the build year from the current year
    age = current_year - yr_built
    return age

# Apply the function to create a new column called "age"
k_df['house_age'] = k_df['yr_built'].apply(get_age)

# Print the first few rows to make sure the new column was added correctly
k_df.head()
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02  437500.0         3       2.25         1970
# 9596    472000620 2014-05-02  790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02  675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02  555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02  440000.0         4       2.25         2160
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 16768     35100     2.0           0     0  ...              0      1977
# 9596       4750     1.0           0     0  ...            900      1951
# 9587      67518     2.0           0     0  ...              0      1979
# 20602      6500     2.0           0     0  ...              0      2012
# 11577      8119     1.0           0     0  ...           1080      1966
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
import pandas as pd
from uszipcode import SearchEngine

# Create a search engine object
search = SearchEngine()


# Define a function to get city names from zip codes
def get_city_from_zip(zipcode):
    try:
        city = search.by_zipcode(zipcode).major_city
    except:
        city = None
    return city

# Apply the function to the Zipcode column of the dataframe
k_df["city"] = k_df["zipcode"].apply(get_city_from_zip)

# Print the resulting dataframe
k_df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02  437500.0         3       2.25         1970
# 9596    472000620 2014-05-02  790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02  675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02  555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02  440000.0         4       2.25         2160
#
#        sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 16768     35100     2.0           0     0  ...      1977             0
# 9596       4750     1.0           0     0  ...      1951             0
# ...

# %%
k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 16768 to 16594
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
k_df['city'].unique()
# Out:
# array(['Issaquah', 'Seattle', 'Snoqualmie', 'Bellevue', 'Bothell',
#        'Redmond', 'Auburn', 'Renton', 'Fall City', 'Woodinville', 'Kent',
#        'Kirkland', 'North Bend', 'Sammamish', 'Federal Way', 'Carnation',
#        'Maple Valley', 'Duvall', 'Kenmore', 'Mercer Island',
#        'Black Diamond', 'Vashon', 'Enumclaw', 'Medina'], dtype=object)

# %%
k_df['city'].nunique()
# Out:
# 24

# %%
#drop columns
k_df=k_df.drop(columns=['id','waterfront','sqft_above','sqft_basement','yr_renovated','lat','long','sqft_living15','sqft_lot15'])
k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 16768 to 16594
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         21613 non-null  datetime64[ns]
#  1   price        21613 non-null  float64
#  2   bedrooms     21613 non-null  int64
#  3   bathrooms    21613 non-null  float64
#  4   sqft_living  21613 non-null  int64
#  5   sqft_lot     21613 non-null  int64
#  6   floors       21613 non-null  float64
#  7   view         21613 non-null  int64
#  8   condition    21613 non-null  int64
#  9   grade        21613 non-null  int64
#  10  yr_built     21613 non-null  int64
#  11  zipcode      21613 non-null  int64
#  12  year         21613 non-null  int64
#  13  house_age    21613 non-null  int64
#  14  city         21613 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 2.6+ MB

# %%
# Separate data by year
k_2014 = k_df[k_df["year"] == 2014]
k_2015 = k_df[k_df["year"] == 2015]

# %%
k_2014
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 16768 2014-05-02  437500.0         3       2.25         1970     35100
# 9596  2014-05-02  790000.0         3       2.50         2600      4750
# 9587  2014-05-02  675000.0         5       2.50         2820     67518
# 20602 2014-05-02  555000.0         4       2.50         3310      6500
# 11577 2014-05-02  440000.0         4       2.25         2160      8119
# ...          ...       ...       ...        ...          ...       ...
# 4081  2014-12-31  905000.0         3       2.50         3520    237402
# 4882  2014-12-31  240000.0         3       1.75         1590      7931
# 6500  2014-12-31  755000.0         3       3.25         3450     15586
# 13152 2014-12-31  575000.0         4       2.50         2280     27441
# 17365 2014-12-31  826000.0         3       1.50         1890      5000
#
#        floors  view  condition  grade  yr_built  zipcode  year  house_age  \
# ...

# %%
k_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14633 entries, 16768 to 17365
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         14633 non-null  datetime64[ns]
#  1   price        14633 non-null  float64
#  2   bedrooms     14633 non-null  int64
#  3   bathrooms    14633 non-null  float64
#  4   sqft_living  14633 non-null  int64
#  5   sqft_lot     14633 non-null  int64
#  6   floors       14633 non-null  float64
#  7   view         14633 non-null  int64
#  8   condition    14633 non-null  int64
#  9   grade        14633 non-null  int64
#  10  yr_built     14633 non-null  int64
#  11  zipcode      14633 non-null  int64
#  12  year         14633 non-null  int64
#  13  house_age    14633 non-null  int64
#  14  city         14633 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 1.8+ MB

# %%
k_2015
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 19910 2015-01-02   430000.0         3       2.50         1950      4949
# 658   2015-01-02   748000.0         4       3.50         2770      3330
# 21189 2015-01-02   530200.0         4       2.50         1880      3853
# 120   2015-01-02   660000.0         3       2.50         2400      6474
# 6633  2015-01-02   782000.0         4       3.50         3780      7769
# ...          ...        ...       ...        ...          ...       ...
# 7898  2015-05-14   183000.0         3       1.00         1170      7320
# 928   2015-05-14   359000.0         2       2.75         1370      1140
# 5637  2015-05-15   450000.0         5       2.00         1870      7344
# 13053 2015-05-24   445500.0         2       1.75         1390      6670
# 16594 2015-05-27  1310000.0         4       2.25         3750      5000
#
#        floors  view  condition  grade  yr_built  zipcode  year  house_age  \
# ...

# %%
k_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6980 entries, 19910 to 16594
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6980 non-null   datetime64[ns]
#  1   price        6980 non-null   float64
#  2   bedrooms     6980 non-null   int64
#  3   bathrooms    6980 non-null   float64
#  4   sqft_living  6980 non-null   int64
#  5   sqft_lot     6980 non-null   int64
#  6   floors       6980 non-null   float64
#  7   view         6980 non-null   int64
#  8   condition    6980 non-null   int64
#  9   grade        6980 non-null   int64
#  10  yr_built     6980 non-null   int64
#  11  zipcode      6980 non-null   int64
#  12  year         6980 non-null   int64
#  13  house_age    6980 non-null   int64
#  14  city         6980 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 872.5+ KB

# %%
taxrate_2014=pd.read_csv('/Users/candicewu/Desktop/propert tax rate 2014.csv')
crime_2014=pd.read_csv('/Users/candicewu/Desktop/area crime 2014.csv')
school_2014=pd.read_csv('/Users/candicewu/Desktop/school rate 2014.csv')
fiveotherfactors_2014=pd.read_csv('/Users/candicewu/Desktop/five factors in 2014.csv')

# %%
taxrate_2014
# Out:
#                    city  2014 typical levy rate
# 0               Seattle                   10.29
# 1                Algona                   14.89
# 2                Auburn                   15.13
# 3            Beaux Arts                    9.93
# 4              Bellevue                    9.52
# 5         Black Diamond                   13.29
# 6               Bothell                   12.27
# 7                Burien                   14.46
# 8             Carnation                   12.87
# 9            Clyde Hill                    9.05
# 10            Covington                   14.02
# 11           Des Moines                   14.77
# 12               Duvall                   14.17
# 13             Enumclaw                   13.29
# 14          Federal Way                   15.75
# 15          Hunts Point                    8.25
# 16             Issaquah                   11.37
# 17              Kenmore                   13.45
# 18                 Kent                   14.14
# ...

# %%
taxrate_2014.isnull().sum()
# Out:
# city                      0
# 2014 typical levy rate    0
# dtype: int64

# %%
# Divide the values in the '2014 typical levy rate' column by 100
taxrate_2014['2014 typical levy rate'] = taxrate_2014['2014 typical levy rate'] / 100
taxrate_2014.sort_values(by='2014 typical levy rate')
# Out:
#                    city  2014 typical levy rate
# 15          Hunts Point                  0.0825
# 38         Yarrow Point                  0.0853
# 9            Clyde Hill                  0.0905
# 23        Mercer Island                  0.0913
# 22               Medina                  0.0938
# 4              Bellevue                  0.0952
# 3            Beaux Arts                  0.0993
# 0               Seattle                  0.1029
# 34            Skykomish                  0.1029
# 29              Redmond                  0.1091
# 19             Kirkland                  0.1095
# 16             Issaquah                  0.1137
# 31            Sammamish                  0.1225
# 6               Bothell                  0.1227
# 27           North Bend                  0.1264
# 37          Woodinville                  0.1283
# 8             Carnation                  0.1287
# 35           Snoqualmie                  0.1314
# 13             Enumclaw                  0.1329
# ...

# %%
crime_2014.sort_values(by='area_crime')
# Out:
#           city area_crime
# 33      Colton          0
# 107     Odessa          0
# 64    Issaquah      1,079
# 15     Bothell      1,096
# 4    Arlington      1,108
# ..         ...        ...
# 138      Selah         91
# 0     Aberdeen        941
# 27    Chewelah         95
# 182        NaN        NaN
# 183                   NaN
#
# [184 rows x 2 columns]

# %%
crime_2014.isnull().sum()
# Out:
# city          1
# area_crime    2
# dtype: int64

# %%
school_2014.sort_values(by='2014_school _rate')
# Out:
#                 city 2014_school _rate
# 150         Quilcene             (n/a)
# 195           Satsop             (n/a)
# 226    College Place             (n/a)
# 101  Anderson Island             (n/a)
# 168             Lind             (n/a)
# ..               ...               ...
# 2        Woodinville         0.9349396
# 13     Mercer Island          0.955636
# 7          Sammamish         0.9635578
# 3          Fall City         0.9710251
# 0             Medina          0.977396
#
# [253 rows x 2 columns]

# %%
school_2014.isnull().sum()
# Out:
# city                 0
# 2014_school _rate    0
# dtype: int64

# %%
school_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               253 non-null    object
#  1   2014_school _rate  253 non-null    object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
fiveotherfactors_2014
# Out:
#         zipcode unemployment _rate travel_time_to_work  \
# 0   ZCTA5 98001               8.0%                29.3
# 1   ZCTA5 98002               9.5%                29.7
# 2   ZCTA5 98003               8.8%                29.1
# 3   ZCTA5 98004               5.5%                18.8
# 4   ZCTA5 98005               7.5%                21.3
# ..          ...                ...                 ...
# 93  ZCTA5 98288              17.6%                27.9
# 94  ZCTA5 98321               7.9%                35.4
# 95  ZCTA5 98323              14.7%                43.2
# 96  ZCTA5 98354               7.2%                25.6
# 97  ZCTA5 98391               6.9%                35.2
#
#    median_household_income total_population median_age
# 0                   72,540           32,194       39.3
# 1                   44,930           33,817       35.3
# 2                   45,563           46,008       35.9
# 3                  100,344           32,587       37.8
# ...

# %%
# Remove the "ZCTA5 " prefix from the values in the 'zipcode' column
fiveotherfactors_2014['zipcode'] = fiveotherfactors_2014['zipcode'].str.replace('ZCTA5 ', '')
fiveotherfactors_2014.head()
# Out:
#   zipcode unemployment _rate travel_time_to_work median_household_income  \
# 0   98001               8.0%                29.3                  72,540
# 1   98002               9.5%                29.7                  44,930
# 2   98003               8.8%                29.1                  45,563
# 3   98004               5.5%                18.8                 100,344
# 4   98005               7.5%                21.3                  85,639
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733       38.0

# %%
# Remove the "%" from the values in the 'unemployment _rate' column
fiveotherfactors_2014['unemployment _rate'] = fiveotherfactors_2014['unemployment _rate'].str.replace('%', '')
fiveotherfactors_2014.head()
# Out:
#   zipcode unemployment _rate travel_time_to_work median_household_income  \
# 0   98001                8.0                29.3                  72,540
# 1   98002                9.5                29.7                  44,930
# 2   98003                8.8                29.1                  45,563
# 3   98004                5.5                18.8                 100,344
# 4   98005                7.5                21.3                  85,639
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733       38.0

# %%
# Use the apply method to convert the column to numeric
fiveotherfactors_2014['unemployment _rate'] = fiveotherfactors_2014['unemployment _rate'].apply(pd.to_numeric, errors='coerce').astype(float)
fiveotherfactors_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   zipcode                  98 non-null     object
#  1   unemployment _rate       95 non-null     float64
#  2   travel_time_to_work      98 non-null     object
#  3   median_household_income  98 non-null     object
#  4   total_population         98 non-null     object
#  5   median_age               98 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 4.7+ KB

# %%
fiveotherfactors_2014['unemployment _rate'] = fiveotherfactors_2014['unemployment _rate']/ 100
fiveotherfactors_2014.head()
# Out:
#   zipcode  unemployment _rate travel_time_to_work median_household_income  \
# 0   98001               0.080                29.3                  72,540
# 1   98002               0.095                29.7                  44,930
# 2   98003               0.088                29.1                  45,563
# 3   98004               0.055                18.8                 100,344
# 4   98005               0.075                21.3                  85,639
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733       38.0

# %%
fiveotherfactors_2014.isnull().sum()
# Out:
# zipcode                    0
# unemployment _rate         3
# travel_time_to_work        0
# median_household_income    0
# total_population           0
# median_age                 0
# dtype: int64

# %%
# Merge the datasets by city
merged_df = pd.merge(k_2014, taxrate_2014, on="city")
merged_df = pd.merge(merged_df, crime_2014, on="city")
merged_df= pd.merge(merged_df, school_2014, on="city")
merged_df
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   437500.0         3       2.25         1970     35100
# 1     2014-05-02   675000.0         5       2.50         2820     67518
# 2     2014-05-02   630000.0         4       2.75         2710     37277
# 3     2014-05-03   379880.0         3       2.50         1650     14054
# 4     2014-05-05   419190.0         2       2.50         1590      1426
# ...          ...        ...       ...        ...          ...       ...
# 14197 2014-11-06  1880000.0         3       2.75         2620     17919
# 14198 2014-11-07   875000.0         3       1.00         1220      8119
# 14199 2014-11-13  2900000.0         5       4.00         5190     14600
# 14200 2014-11-18   865000.0         3       1.50         1530     10827
# 14201 2014-11-26  1555000.0         5       2.50         2870     16238
#
#        floors  view  condition  grade  yr_built  zipcode  year  house_age  \
# ...

# %%
#change the zipcode type to match with merged_df
fiveotherfactors_2014['zipcode']=fiveotherfactors_2014['zipcode'].astype('int64')
fiveotherfactors_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   zipcode                  98 non-null     int64
#  1   unemployment _rate       95 non-null     float64
#  2   travel_time_to_work      98 non-null     object
#  3   median_household_income  98 non-null     object
#  4   total_population         98 non-null     object
#  5   median_age               98 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.7+ KB

# %%
# Merge the datasets by zipcode
merged_df_2014= pd.merge(merged_df, fiveotherfactors_2014, on="zipcode")
merged_df_2014
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   437500.0         3       2.25         1970     35100
# 1     2014-05-02   630000.0         4       2.75         2710     37277
# 2     2014-05-03   379880.0         3       2.50         1650     14054
# 3     2014-05-05   525888.0         5       1.75         2550     71874
# 4     2014-05-05   410000.0         3       2.25         1800     36704
# ...          ...        ...       ...        ...          ...       ...
# 14197 2014-11-06  1880000.0         3       2.75         2620     17919
# 14198 2014-11-07   875000.0         3       1.00         1220      8119
# 14199 2014-11-13  2900000.0         5       4.00         5190     14600
# 14200 2014-11-18   865000.0         3       1.50         1530     10827
# 14201 2014-11-26  1555000.0         5       2.50         2870     16238
#
#        floors  view  condition  grade  ...  house_age      city  \
# ...

# %%
merged_df_2014.info()
#14202
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14202 entries, 0 to 14201
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     14202 non-null  datetime64[ns]
#  1   price                    14202 non-null  float64
#  2   bedrooms                 14202 non-null  int64
#  3   bathrooms                14202 non-null  float64
#  4   sqft_living              14202 non-null  int64
#  5   sqft_lot                 14202 non-null  int64
#  6   floors                   14202 non-null  float64
#  7   view                     14202 non-null  int64
#  8   condition                14202 non-null  int64
#  9   grade                    14202 non-null  int64
#  10  yr_built                 14202 non-null  int64
#  11  zipcode                  14202 non-null  int64
#  12  year                     14202 non-null  int64
#  13  house_age                14202 non-null  int64
# ...

# %%
merged_df_2014.isnull().sum()
# Out:
# date                       0
# price                      0
# bedrooms                   0
# bathrooms                  0
# sqft_living                0
# sqft_lot                   0
# floors                     0
# view                       0
# condition                  0
# grade                      0
# yr_built                   0
# zipcode                    0
# year                       0
# house_age                  0
# city                       0
# 2014 typical levy rate     0
# area_crime                 0
# 2014_school _rate          0
# unemployment _rate         0
# travel_time_to_work        0
# median_household_income    0
# total_population           0
# median_age                 0
# dtype: int64

# %%
merged_df_2014['city'].nunique()
# Out:
# 20

# %%
merged_df_2014.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'view', 'condition', 'grade', 'yr_built', 'zipcode', 'year',
#        'house_age', 'city', '2014 typical levy rate', 'area_crime',
#        '2014_school _rate', 'unemployment _rate', 'travel_time_to_work',
#        'median_household_income', 'total_population', 'median_age'],
#       dtype='object')

# %%
# create a dictionary to map old column names to new column names
new_column_names={ '2014_tax_amount':'tax_amount', 
                  '2014 typical levy rate':'typical_levy_rate',
                 '2014_school _rate':'school_rate', 
                'unemployment _rate':'unemployment_rate'}

# use the rename function to change the column names
merged_df_2014 = merged_df_2014.rename(columns=new_column_names)
merged_df_2014
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02   437500.0         3       2.25         1970     35100
# 1     2014-05-02   630000.0         4       2.75         2710     37277
# 2     2014-05-03   379880.0         3       2.50         1650     14054
# 3     2014-05-05   525888.0         5       1.75         2550     71874
# 4     2014-05-05   410000.0         3       2.25         1800     36704
# ...          ...        ...       ...        ...          ...       ...
# 14197 2014-11-06  1880000.0         3       2.75         2620     17919
# 14198 2014-11-07   875000.0         3       1.00         1220      8119
# 14199 2014-11-13  2900000.0         5       4.00         5190     14600
# 14200 2014-11-18   865000.0         3       1.50         1530     10827
# 14201 2014-11-26  1555000.0         5       2.50         2870     16238
#
#        floors  view  condition  grade  ...  house_age      city  \
# ...

# %%
taxrate_2015=pd.read_csv('/Users/candicewu/Desktop/propert tax rate 2015.csv')
crime_2015=pd.read_csv('/Users/candicewu/Desktop/area crime 2015.csv')
school_2015=pd.read_csv('/Users/candicewu/Desktop/school rate 2015.csv')
fiveotherfactors_2015=pd.read_csv('/Users/candicewu/Desktop/five factors in 2015.csv')

# %%
taxrate_2015.head()
# Out:
#          city  2015 typical levy rate
# 0     Seattle                    9.27
# 1      Algona                   13.91
# 2      Auburn                   14.16
# 3  Beaux Arts                    9.06
# 4    Bellevue                    8.87

# %%
taxrate_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   city                    40 non-null     object
#  1   2015 typical levy rate  40 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 768.0+ bytes

# %%
# Divide the values in the '2015 property tax rate' column by 100
taxrate_2015['2015 typical levy rate'] = taxrate_2015['2015 typical levy rate'] / 100
taxrate_2015.head()
# Out:
#          city  2015 typical levy rate
# 0     Seattle                  0.0927
# 1      Algona                  0.1391
# 2      Auburn                  0.1416
# 3  Beaux Arts                  0.0906
# 4    Bellevue                  0.0887

# %%
crime_2015.head()
# Out:
#              city area_crime
# 0        Aberdeen        874
# 1  Airway Heights        353
# 2          Algona         71
# 3       Anacortes        509
# 4      Arlington3        877

# %%
school_2015.head()
# Out:
#            city  2015 school rate
# 0        Medina          0.991565
# 1      Winthrop          0.937079
# 2   Woodinville          0.937018
# 3     Fall City          0.932920
# 4  Liberty Lake          0.920337

# %%
fiveotherfactors_2015.head()
# Out:
#    zipcode unemployment _rate travel_time_to_work median_household_income  \
# 0    98001              7.10%                29.8                  71,555
# 1    98002              7.60%                30.1                  45,078
# 2    98003              7.70%                29.8                  46,250
# 3    98004              5.50%                19.3                 102,374
# 4    98005              6.80%                21.9                  88,940
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733         38

# %%
fiveotherfactors_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   zipcode                  92 non-null     int64
#  1   unemployment _rate       92 non-null     object
#  2   travel_time_to_work      92 non-null     object
#  3   median_household_income  92 non-null     object
#  4   total_population         92 non-null     object
#  5   median_age               92 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 4.4+ KB

# %%
# Remove the "%" from the values in the 'unemployment _rate' column
fiveotherfactors_2015['unemployment _rate'] = fiveotherfactors_2015['unemployment _rate'].str.replace('%', '')
fiveotherfactors_2015.head()
# Out:
#    zipcode unemployment _rate travel_time_to_work median_household_income  \
# 0    98001               7.10                29.8                  71,555
# 1    98002               7.60                30.1                  45,078
# 2    98003               7.70                29.8                  46,250
# 3    98004               5.50                19.3                 102,374
# 4    98005               6.80                21.9                  88,940
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733         38

# %%
# Use the apply method to convert the column to numeric
fiveotherfactors_2015['unemployment _rate'] = fiveotherfactors_2015['unemployment _rate'].apply(pd.to_numeric, errors='coerce').astype(float)
fiveotherfactors_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   zipcode                  92 non-null     int64
#  1   unemployment _rate       88 non-null     float64
#  2   travel_time_to_work      92 non-null     object
#  3   median_household_income  92 non-null     object
#  4   total_population         92 non-null     object
#  5   median_age               92 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.4+ KB

# %%
fiveotherfactors_2015.head()
# Out:
#    zipcode  unemployment _rate travel_time_to_work median_household_income  \
# 0    98001                 7.1                29.8                  71,555
# 1    98002                 7.6                30.1                  45,078
# 2    98003                 7.7                29.8                  46,250
# 3    98004                 5.5                19.3                 102,374
# 4    98005                 6.8                21.9                  88,940
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733         38

# %%
# Divide the values in the 'unemployment _rate' column by 100
fiveotherfactors_2015['unemployment _rate'] = fiveotherfactors_2015['unemployment _rate'] / 100
fiveotherfactors_2015.head()
# Out:
#    zipcode  unemployment _rate travel_time_to_work median_household_income  \
# 0    98001               0.071                29.8                  71,555
# 1    98002               0.076                30.1                  45,078
# 2    98003               0.077                29.8                  46,250
# 3    98004               0.055                19.3                 102,374
# 4    98005               0.068                21.9                  88,940
#
#   total_population median_age
# 0           32,194       39.3
# 1           33,817       35.3
# 2           46,008       35.9
# 3           32,587       37.8
# 4           17,733         38

# %%
# Merge the datasets by city
merged_df = pd.merge(k_2015, taxrate_2015, on="city")
merged_df = pd.merge(merged_df, crime_2015, on="city")
merged_df= pd.merge(merged_df, school_2015, on="city")
merged_df
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2015-01-02   748000.0         4       3.50         2770      3330
# 1    2015-01-02   782000.0         4       3.50         3780      7769
# 2    2015-01-02   476000.0         3       2.50         1440      3840
# 3    2015-01-02   762500.0         5       3.50         3290      5880
# 4    2015-01-05   713000.0         4       3.25         2840     54400
# ...         ...        ...       ...        ...          ...       ...
# 6367 2015-04-08  1651000.0         4       3.25         3640     13530
# 6368 2015-04-08  1200000.0         4       3.00         2150      8119
# 6369 2015-04-10  2575000.0         5       3.00         4780     20440
# 6370 2015-04-21  2250000.0         5       5.25         3410      8118
# 6371 2015-05-13  1620000.0         4       2.25         2350     17709
#
#       floors  view  condition  grade  yr_built  zipcode  year  house_age  \
# ...

# %%
# Merge the datasets by zipcode
merged_df_2015= pd.merge(merged_df, fiveotherfactors_2015, on="zipcode")
merged_df_2015
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2015-01-02   748000.0         4       3.50         2770      3330
# 1    2015-01-02   782000.0         4       3.50         3780      7769
# 2    2015-01-02   762500.0         5       3.50         3290      5880
# 3    2015-01-06   405000.0         3       1.00         1250      7280
# 4    2015-01-07   596500.0         4       2.25         1770      8505
# ...         ...        ...       ...        ...          ...       ...
# 6367 2015-04-08  1651000.0         4       3.25         3640     13530
# 6368 2015-04-08  1200000.0         4       3.00         2150      8119
# 6369 2015-04-10  2575000.0         5       3.00         4780     20440
# 6370 2015-04-21  2250000.0         5       5.25         3410      8118
# 6371 2015-05-13  1620000.0         4       2.25         2350     17709
#
#       floors  view  condition  grade  ...  house_age     city  \
# ...

# %%
merged_df_2015.info()
#    6372
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6372 entries, 0 to 6371
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     6372 non-null   datetime64[ns]
#  1   price                    6372 non-null   float64
#  2   bedrooms                 6372 non-null   int64
#  3   bathrooms                6372 non-null   float64
#  4   sqft_living              6372 non-null   int64
#  5   sqft_lot                 6372 non-null   int64
#  6   floors                   6372 non-null   float64
#  7   view                     6372 non-null   int64
#  8   condition                6372 non-null   int64
#  9   grade                    6372 non-null   int64
#  10  yr_built                 6372 non-null   int64
#  11  zipcode                  6372 non-null   int64
#  12  year                     6372 non-null   int64
#  13  house_age                6372 non-null   int64
# ...

# %%
merged_df_2015.isnull().sum()
# Out:
# date                       0
# price                      0
# bedrooms                   0
# bathrooms                  0
# sqft_living                0
# sqft_lot                   0
# floors                     0
# view                       0
# condition                  0
# grade                      0
# yr_built                   0
# zipcode                    0
# year                       0
# house_age                  0
# city                       0
# 2015 typical levy rate     0
# area_crime                 0
# 2015 school rate           0
# unemployment _rate         0
# travel_time_to_work        0
# median_household_income    0
# total_population           0
# median_age                 0
# dtype: int64

# %%
merged_df_2015['city'].unique()
# Out:
# array(['Redmond', 'Issaquah', 'Seattle', 'Sammamish', 'Renton',
#        'Kirkland', 'Kent', 'Federal Way', 'Kenmore', 'Auburn',
#        'Woodinville', 'Black Diamond', 'Maple Valley', 'North Bend',
#        'Bothell', 'Carnation', 'Duvall', 'Mercer Island', 'Enumclaw',
#        'Medina'], dtype=object)

# %%
merged_df_2015['city'].nunique()
# Out:
# 20

# %%
# Check for duplicates
duplicates = merged_df_2015[merged_df_2015.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, view, condition, grade, yr_built, zipcode, year, house_age, city, 2015 typical levy rate, area_crime, 2015 school rate, unemployment _rate, travel_time_to_work, median_household_income, total_population, median_age]
# Index: []
#
# [0 rows x 23 columns]

# %%
merged_df_2015.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'view', 'condition', 'grade', 'yr_built', 'zipcode', 'year',
#        'house_age', 'city', '2015 typical levy rate', 'area_crime',
#        '2015 school rate', 'unemployment _rate', 'travel_time_to_work',
#        'median_household_income', 'total_population', 'median_age'],
#       dtype='object')

# %%
# create a dictionary to map old column names to new column names
new_column_names={ '2015_tax_amount':'tax_amount', 
                  '2015 typical levy rate':'typical_levy_rate',
                 '2015 school rate':'school_rate', 
                'unemployment _rate':'unemployment_rate'}

# use the rename function to change the column names
merged_df_2015 = merged_df_2015.rename(columns=new_column_names)
merged_df_2015
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2015-01-02   748000.0         4       3.50         2770      3330
# 1    2015-01-02   782000.0         4       3.50         3780      7769
# 2    2015-01-02   762500.0         5       3.50         3290      5880
# 3    2015-01-06   405000.0         3       1.00         1250      7280
# 4    2015-01-07   596500.0         4       2.25         1770      8505
# ...         ...        ...       ...        ...          ...       ...
# 6367 2015-04-08  1651000.0         4       3.25         3640     13530
# 6368 2015-04-08  1200000.0         4       3.00         2150      8119
# 6369 2015-04-10  2575000.0         5       3.00         4780     20440
# 6370 2015-04-21  2250000.0         5       5.25         3410      8118
# 6371 2015-05-13  1620000.0         4       2.25         2350     17709
#
#       floors  view  condition  grade  ...  house_age     city  \
# ...

# %%
#merged_df_2015.to_csv('/Users/candicewu/Desktop/merged_df_2015.csv', index=False)

# %%
#merged_df_2014.to_csv('/Users/candicewu/Desktop/merged_df_2014.csv', index=False)

# %%
# concatenate the two dataframes vertically using the concat function
concatenated_df = pd.concat([merged_df_2014, merged_df_2015], axis=0)
concatenated_df
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0    2014-05-02   437500.0         3       2.25         1970     35100
# 1    2014-05-02   630000.0         4       2.75         2710     37277
# 2    2014-05-03   379880.0         3       2.50         1650     14054
# 3    2014-05-05   525888.0         5       1.75         2550     71874
# 4    2014-05-05   410000.0         3       2.25         1800     36704
# ...         ...        ...       ...        ...          ...       ...
# 6367 2015-04-08  1651000.0         4       3.25         3640     13530
# 6368 2015-04-08  1200000.0         4       3.00         2150      8119
# 6369 2015-04-10  2575000.0         5       3.00         4780     20440
# 6370 2015-04-21  2250000.0         5       5.25         3410      8118
# 6371 2015-05-13  1620000.0         4       2.25         2350     17709
#
#       floors  view  condition  grade  ...  house_age      city  \
# ...

# %%
concatenated_df.isnull().sum()
# Out:
# date                       0
# price                      0
# bedrooms                   0
# bathrooms                  0
# sqft_living                0
# sqft_lot                   0
# floors                     0
# view                       0
# condition                  0
# grade                      0
# yr_built                   0
# zipcode                    0
# year                       0
# house_age                  0
# city                       0
# typical_levy_rate          0
# area_crime                 0
# school_rate                0
# unemployment_rate          0
# travel_time_to_work        0
# median_household_income    0
# total_population           0
# median_age                 0
# dtype: int64

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20574 entries, 0 to 6371
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     20574 non-null  datetime64[ns]
#  1   price                    20574 non-null  float64
#  2   bedrooms                 20574 non-null  int64
#  3   bathrooms                20574 non-null  float64
#  4   sqft_living              20574 non-null  int64
#  5   sqft_lot                 20574 non-null  int64
#  6   floors                   20574 non-null  float64
#  7   view                     20574 non-null  int64
#  8   condition                20574 non-null  int64
#  9   grade                    20574 non-null  int64
#  10  yr_built                 20574 non-null  int64
#  11  zipcode                  20574 non-null  int64
#  12  year                     20574 non-null  int64
#  13  house_age                20574 non-null  int64
# ...

# %%
concatenated_df.to_csv('/Users/candicewu/Desktop/merged dataset.csv',index=False)
